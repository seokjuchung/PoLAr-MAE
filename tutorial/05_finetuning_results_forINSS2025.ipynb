# %% [markdown]
# # Fine-tuning for Semantic Segmentation - Results
#
# This contains some code for inspecting the outputs of the model fine-tuned for semantic segmentation.

# %%
from polarmae.datasets import PILArNetDataModule
import torch

# Turn off gradient tracking so we don't run out of memory
torch.set_grad_enabled(False);

# %% [markdown]
# Set up the dataset as usual

# %%
dataset = PILArNetDataModule(
    # data_path=f'/home/sc5303/sbnd_data/inss2025/data/schung_xyze_1e4.h5',
    data_path=f'/home/sc5303/sbnd_data/inss2025/data/schung_xyze_1e4.h5',
    batch_size=32,
    num_workers=0,
    dataset_kwargs={
        'emin': 1.0e-3,                      # min energy for log transform
        'emax': 20.0,                        # max energy for log transform
        'energy_threshold': 0.13,            # remove points with energy < 0.13
        'remove_low_energy_scatters': False,  # remove low energy scatters (PID=4)
        'maxlen': -1,                        # max number of events to load
        'min_points': 0,                  # min number of points/event to load
    }
)
dataset.setup()
# Out:
# INFO:polarmae.datasets.PILArNet:[rank: 0] self.emin=0.001, self.emax=20.0, self.energy_threshold=0.13, self.remove_low_energy_scatters=False
# INFO:polarmae.datasets.PILArNet:[rank: 0] Building index
# INFO:polarmae.datasets.PILArNet:[rank: 0] 10000 point clouds were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] 1 files were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] self.emin=0.001, self.emax=20.0, self.energy_threshold=0.13, self.remove_low_energy_scatters=False
# INFO:polarmae.datasets.PILArNet:[rank: 0] Building index
# INFO:polarmae.datasets.PILArNet:[rank: 0] 10000 point clouds were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] 1 files were loaded

# %% [markdown]
# Download and instantiate fine-tuned model

# %%
from polarmae.models.finetune import SemanticSegmentation
from polarmae.utils.checkpoint import load_finetune_checkpoint


model = load_finetune_checkpoint(SemanticSegmentation,
                                 '/exp/sbnd/data/users/sc5303/inss2025/PoLAr-MAE/tutorial/polarmae_fft_segsem.ckpt',
                                 data_path=dataset.hparams.data_path,
                                 pretrained_ckpt_path='/exp/sbnd/data/users/sc5303/inss2025/PoLAr-MAE/tutorial/polarmae_pretrain.ckpt').cuda()
model.eval();
# Out:
# INFO:polarmae.layers.grouping:[rank: 0] Using CNMS for grouping. Using `num_groups` as the K in the ball query (2048)! Make sure it's not too large!
# INFO:polarmae.datasets.PILArNet:[rank: 0] self.emin=0.01, self.emax=20.0, self.energy_threshold=0.13, self.remove_low_energy_scatters=True
# INFO:polarmae.datasets.PILArNet:[rank: 0] Building index
# INFO:polarmae.datasets.PILArNet:[rank: 0] 9758 point clouds were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] 1 files were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] self.emin=0.01, self.emax=20.0, self.energy_threshold=0.13, self.remove_low_energy_scatters=True
# INFO:polarmae.datasets.PILArNet:[rank: 0] Building index
# INFO:polarmae.datasets.PILArNet:[rank: 0] 9758 point clouds were loaded
# INFO:polarmae.datasets.PILArNet:[rank: 0] 1 files were loaded
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# INFO:polarmae.models.base:[rank: 0] Loading pretrained checkpoint from './polarmae_pretrain.ckpt'.
# WARNING:polarmae.models.base:[rank: 0] Missing keys: ['upsampler.mlp_convs.0.weight', 'upsampler.mlp_convs.1.weight', 'upsampler.mlp_bns.0.weight', 'upsampler.mlp_bns.0.bias', 'upsampler.mlp_bns.0.running_mean', 'upsampler.mlp_bns.0.running_var', 'upsampler.mlp_bns.1.weight', 'upsampler.mlp_bns.1.bias', 'upsampler.mlp_bns.1.running_mean', 'upsampler.mlp_bns.1.running_var', 'seg_head.conv1.weight', 'seg_head.bn1.weight', 'seg_head.bn1.bias', 'seg_head.bn1.running_mean', 'seg_head.bn1.running_var', 'seg_head.conv2.weight', 'seg_head.bn2.weight', 'seg_head.bn2.bias', 'seg_head.bn2.running_mean', 'seg_head.bn2.running_var', 'seg_head.conv3.weight', 'seg_head.conv3.bias', 'loss_func.weight']
# WARNING:polarmae.models.base:[rank: 0] Unexpected keys: ['increase_dim.weight', 'increase_dim.bias', 'equivariant_patch_encoder.first_conv.0.weight', 'equivariant_patch_encoder.first_conv.1.weight', 'equivariant_patch_encoder.first_conv.1.bias', 'equivariant_patch_encoder.first_conv.1.running_mean', 'equivariant_patch_encoder.first_conv.1.running_var', 'equivariant_patch_encoder.first_conv.3.weight', 'equivariant_patch_encoder.first_conv.3.bias', 'equivariant_patch_encoder.second_conv.0.weight', 'equivariant_patch_encoder.second_conv.1.weight', 'equivariant_patch_encoder.second_conv.1.bias', 'equivariant_patch_encoder.second_conv.1.running_mean', 'equivariant_patch_encoder.second_conv.1.running_var', 'equivariant_patch_encoder.second_conv.3.weight', 'equivariant_patch_encoder.second_conv.3.bias', 'equivariant_patch_encoder.position_encoder.time_embed.1.weight', 'equivariant_patch_encoder.position_encoder.time_embed.1.bias', 'energy_decoder.weight', 'energy_decoder.bias']
# INFO:polarmae.models.finetune.semantic_segmentation:[rank: 0] 🔥  Loaded pretrained checkpoint.
# INFO:polarmae.models.finetune.semantic_segmentation:[rank: 0] 🔥  Not freezing encoder.
# INFO:polarmae.utils.checkpoint:[rank: 0] Loading state dict. There should be no missing or unexpected keys below here.
# INFO:polarmae.utils.checkpoint:[rank: 0] Missed: []
# INFO:polarmae.utils.checkpoint:[rank: 0] Unexpected: []

# %% [markdown]
# The forward pass of the model returns the class logits and a point mask. We can get predictions by taking the argmax of the logits.

# %%
from polarmae.utils import transforms
from math import sqrt

normalize = transforms.PointcloudCenterAndNormalize(
                    center=[384, 384, 384],
                    scale_factor=1 / (768 * sqrt(3) / 2)
                )


batch = next(iter(dataset.val_dataloader()))
points = batch['points'].cuda()

# in the past (when this model was trained), the centering and
# scaling was done in the data module. now it's done in the model
# in train_transformations and val_transformations.
# for backwards compatibility, we check if there are zero transforms
# in val_transformations and apply normalization if so.
if len(model.val_transformations.transforms) > 0:
    points = model.val_transformations(points)
else:
    points = normalize(points) # scale and normalize
lengths = batch['lengths'].cuda()
# labels = batch['semantic_id'].cuda().squeeze(-1)
output = model(points, lengths)
pred = output['id_pred']
# Out:
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([646, 687, 105, 118, 117, 152, 189,  74, 216, 494, 434, 857, 146, 326,
#         230, 200, 127, 533, 578, 185, 447, 309, 432,  87, 160, 595, 269, 192,
#         292, 610, 628,  48], device='cuda:0') > 512)! This should not happen!

# %%
point_mask = output['point_mask']
pred = pred[point_mask]

# %%
from polarmae.utils import transforms
from math import sqrt

normalize = transforms.PointcloudCenterAndNormalize(
                    center=[384, 384, 384],
                    scale_factor=1 / (768 * sqrt(3) / 2)
                )

val_loader = dataset.val_dataloader()  # or DataLoader(dataset.val_dataset, batch_size=..., shuffle=False)


batch_idx = 0

with torch.no_grad():
    for batch in val_loader:
        points = batch['points'].cuda()
        if len(model.val_transformations.transforms) > 0:
            points = model.val_transformations(points)
        else:
            points = normalize(points) # scale and normalize
        lengths = batch['lengths'].cuda()
    
        output = model(points, lengths)
        pred = output['id_pred']
        point_mask = output['point_mask']
        pred = pred[point_mask]
        
        # Save all predictions from this batch
        import numpy as np
        np.save(f'predictions/predictions_batch_{batch_idx}.npy', pred.cpu().numpy())
        batch_idx+=1
# Out:
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([550, 768, 275, 206, 132, 225, 180, 427, 273, 254, 156, 710, 197, 211,
#         153, 591,  47, 218, 163, 336, 303, 196, 372, 303, 507, 641, 281,  97,
#         257, 637, 231, 514], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([393, 600, 297, 415, 235, 118, 870, 328, 187, 610, 430, 353, 194, 601,
#         166, 123, 573, 265, 358, 230, 199, 158, 286, 427, 151, 802, 578, 129,
#         335, 255, 118, 187], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([551, 312, 249, 187, 259, 191, 485, 252, 191, 416, 362, 110, 303, 479,
#         238, 393, 232, 226, 141, 394, 188, 349,  61, 228, 314, 204, 381, 293,
#          47, 216, 190, 221], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 30, 171, 252,  67, 160, 227, 976, 241, 153, 705, 362, 202, 288, 144,
#         278, 246, 139, 535, 131, 145, 216,  98, 385, 252, 638, 519, 321, 168,
#         375, 309, 220, 204], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([848, 952, 336, 714,  73, 230, 645, 154, 257, 262, 241, 395, 419, 607,
#         430, 319, 226, 479, 432, 232, 584, 334, 513, 685, 664, 288, 305, 156,
#         270, 239, 133, 297], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([157, 307, 398, 105, 332, 358, 185, 118, 249, 266, 276, 618, 149, 246,
#         179, 129, 337, 354, 295, 216, 264, 759, 389, 305,  93, 348,  89, 546,
#         344, 717, 622, 533], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([246, 193, 280, 304, 445, 265, 202, 630, 181, 194, 269, 382, 427, 488,
#         166, 494, 371,  59, 111,  98, 313, 151,  41, 369, 277, 277, 160, 119,
#         289, 220, 216, 250], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([268, 287, 438, 313, 336, 235, 421, 186, 868, 342, 145, 285, 434, 283,
#         294, 318, 198, 279, 293, 662, 182, 135, 264, 462, 322, 203, 893, 114,
#         235, 213, 891, 193], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 203,  421,  277,  367,  190,  329,  254,  893,  126,  149,  167,  121,
#          858,  863,  266,  463,   72,  614,  235,  181,  166,  549,  928,  249,
#          170,  143,  103, 1002,  592,  387,  273,  522], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 232,  289,  257,  287,  228,  167,  233,   57,   55,  211,  218,  390,
#          181,  108,  981,  216,  290,  806,  190,  633,  591,  263,  778,  466,
#          855,  287,  372,  498,  183, 1001,  572,  239], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([214, 353, 393, 660, 179, 649, 180, 260, 693, 611, 156, 154,  77, 152,
#         443, 357, 240, 311, 181, 300, 123, 562, 620, 306, 270, 288, 345, 195,
#         119, 179, 232, 156], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 128,  216,  662,  139,  536,  560,  324,  350,  192,  176,  516,  123,
#          726, 1040,  170,  282,  214,  471,  243,  257,  689,  176,  394,  374,
#          304,  333,  234,  148,  316,  297,  207,  275], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor
device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([124, 170, 445, 281, 198, 770, 165, 688, 693, 592, 362, 165, 182, 171,
#         445, 443, 104, 203, 209, 199, 246, 942, 246, 264, 213, 251, 900, 360,
#          93, 254, 265, 230], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([135, 158, 257, 244, 870, 356, 532, 254, 180, 220, 264, 462,  97, 557,
#         241, 348, 141, 229, 185, 764, 182, 138, 223, 192, 461, 897, 152, 657,
#         320, 214, 254, 367], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([158, 292, 105, 200, 596, 493, 150, 207, 261, 155, 261, 286, 160, 615,
#         224, 197, 351, 573, 499, 328, 934, 112, 243, 522, 200, 532, 203, 214,
#         202, 134, 930, 301], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([856, 466, 165, 190, 714, 196, 249, 385, 417, 241, 156, 524, 209, 252,
#         276,  89, 189, 521, 204, 191, 457, 200, 103, 243,  47,  82, 421, 218,
#         392, 213, 374, 318], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([406, 187, 832, 239, 188, 258, 759, 127, 344, 534, 640, 351, 267, 106,
#         782, 628, 439, 668, 341, 226,  90, 864, 306, 142, 152, 182, 691, 211,
#         234, 399, 228, 567], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([264, 129, 141, 308, 586, 206, 285, 257, 295, 187, 662, 113, 323, 379,
#         211, 105, 121, 292,  68, 195, 281, 287, 231, 327, 291, 889, 767, 204,
#         330, 226, 158, 337], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 303,  271,   88,  293,  182,  396,  417,  137,  225,  477,  225,  293,
#          281,  186,  501,  257,  160,  289,  225,  206,  282,  272, 1051,  462,
#          189,  633,  109,  258,  112,  412,  232,  725], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([340, 714, 289, 391, 257, 196, 241, 360, 626, 135, 261, 335, 388, 400,
#         213, 900, 217, 683, 107, 182, 300, 477, 215, 423, 421,  72, 405, 106,
#         224, 266, 359, 231], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([402, 222, 459, 136, 312, 164, 264, 147, 674, 384, 222, 641,  93, 283,
#         279, 163, 183, 334,  73, 727, 706, 638, 224, 196, 218, 762, 183,  99,
#         431, 497, 510, 220], device='cuda:0') > 512)! This should not happen!
# WARNING:polarmae.layers.grouping:[rank: 0] Some events had more groups than the context length allows (tensor([ 733,  359,  611,  170,  153,  268,  152,  414,   26,  362,  223,  176,
#          291,  956,  463,   83,  235,  283,  234,  103,  499,  163,  251,  157,
#          115,  247,  160,  205,  319,  202,  529, 1061], device='cuda:0') > 512)! This should not happen!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 23
#      20     points = normalize(points) # scale and normalize
#      21 lengths = batch['lengths'].cuda()
# ---> 23 output = model(points, lengths)
#      24 pred = output['id_pred']
#      25 point_mask = output['point_mask']
#
# File /exp/sbnd/data/users/sc5303/apptainer_cache/envs/polarmae/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /exp/sbnd/data/users/sc5303/apptainer_cache/envs/polarmae/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /exp/sbnd/data/users/sc5303/inss2025/PoLAr-MAE/polarmae/models/finetune/semantic_segmentation.py:210, in SemanticSegmentation.forward(self, points, lengths, labels, class_slice, return_logits)
#     205         global_feature = torch.cat(
#     206             [token_features_max, token_features_mean], dim=-1
#     207         )  # (B, 2*C')
#     209 # upsample token features to point features a la PointNet++
# --> 210 point_mask = torch.arange(lengths.max(), device=lengths.device).expand(
#     211     len(lengths), -1
#     212 ) < lengths.unsqueeze(-1)
#     214 x, idx = self.upsampler(
#     215     points[..., :3],
#     216     out['centers'][:, :, :3],
#    (...)    221     point_mask,
#     222 )  # (B, N, 384)
#     224 if self.seg_decoder is None and self.condition_global_features:
#
# KeyboardInterrupt:
